# %%
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import time
max_results_per_city = 50
city_set = ['Hyderabad%2C+Telangana','hyderbad%2C+Telangana','Chennai%2C+Tamil+Nadu','Bangalore%2C+Karnataka','Bengaluru%2C+Karnataka','Noida%2C+Uttar+Pradesh','Pune%2C+Maharashtra','Delhi','Delhi%2C+Delhi','Gurgaon%2C+Haryana']
col = ['JOB_TITLE', 'COMPANY_NAME', 'LOCATION', 'SUMMARY']
comp=['Wipro','ICS Consultancy Services','Oracle','Accenture','IBM','Infosys','TCS','Amazon','Tech Mahindra','Swiggy',' L&T infotech','Flipkart','Ola','Uber','Zomato','Cognizant']
sample_df = pd.DataFrame(columns = col)
res={}
res1={}
#scraping code:
for city in city_set:
    for start in range(0, max_results_per_city,10):
        o=0
        page = requests.get("https://www.indeed.co.in/jobs?q=software+developer&l=" + str(city) + "&start=" + str(start))
        time.sleep(1)  #ensuring at least 1 second between page grabs
        soup = BeautifulSoup(page.text, 'html.parser')
        for div in soup.find_all(name='div', attrs={'class':'row'}):
    #specifying row num for index of job posting in dataframe
            num = (len(sample_df) + 1) 
    #creating an empty list to hold the data for each posting
            job_post = [] 
    #grabbing job title
            for a in div.find_all(name='a', attrs={'data-tn-element':'jobTitle'}):
                         job_post.append(a['title']) 
    #grabbing company name
            company = div.find_all(name='span', attrs={'class':'company'}) 
            if len(company) > 0:
                        for b in company:
                            if b.text.strip() in comp:
                                job_post.append(b.text.strip())
                                if b.text.strip() in res.keys():
                                    res[b.text.strip()]+=1
                                else:
                                    res[b.text.strip()]=1
            else: 
                        sec_try = div.find_all(name='span', attrs={'class':'result-link-source'})
                        for span in sec_try:
                            if span.text.strip() in comp:
                                o=1
                                job_post.append(span.text.strip()) 
                                if span.text.strip() in res.keys():
                                    res[b.text.strip()]+=1
                                else:
                                    res[b.text.strip()]=1
    #grabbing location name
            c = div.findAll('span', attrs={'class': 'location'}) 
            for span in c:
                    job_post.append(span.text.strip())
                    if span.text.strip() in res1.keys() and o==1:
                            res1[span.text.strip()]+=1
                    else:
                            res1[span.text.strip()]=1
    #grabbing summary text
            d = div.findAll('div', attrs={'class': 'summary'}) #it conatins the exprience for the job
            for span in d:
                        s=span.text.strip()
                        s1=s.replace('\n',"")
                        job_post.append(s1)   
    #appending list of job post info to dataframe at index num
            if(len(job_post)>3):
                sample_df = sample_df.append({'JOB_TITLE' :job_post[0], 'COMPANY_NAME' :job_post[1], 'LOCATION' : job_post[2],'SUMMARY':job_post[3]},ignore_index = True)
print(sample_df)
print()
print("NO OF SOFTWARE DEVELOPERS JOBS BASED ON COMAPNIES")
for i in res:
    print(i,"    ",res[i],end="\n")
print()
print("NO OF SOFTWARE DEVELOPERS JOBS BASED ON CITIES")
for j in res1:
    print(j,"    ",res1[j],end="\n")
# Out:
#                                             JOB_TITLE COMPANY_NAME  \
# 0                                Software Developer 4       Oracle
# 1                                Software Developer 4       Oracle
# 2   Software Developer - Application Development T...       Oracle
# 3                            Applications Developer 2       Oracle
# 4                   ASP.NET MVC Application Developer    Accenture
# 5         Java Standard Edition Application Developer    Accenture
# 6                       Node.js Application Developer    Accenture
# 7                                Software Developer 3       Oracle
# 8   Software Developer - Application Development T...       Oracle
# 9      Software Developer 3 - Infra/Tools Development       Oracle
# 10     Software Developer 3 - Infra/Tools Development       Oracle
# 11                  ASP.NET MVC Application Developer    Accenture
# 12                           Applications Developer 3       Oracle
# 13                               Full Stack Developer       Oracle
# 14  Python Programming Language Application Developer    Accenture
# 15               TIBCO Spotfire Application Developer    Accenture
# 16                               Software Developer 3       Oracle
# 17             Workday Core HCM Application Developer    Accenture
# 18     Software Developer 3 - Infra/Tools Development       Oracle
# 19                  ASP.NET MVC Application Developer    Accenture
# 20                           Applications Developer 3       Oracle
# 21                               Full Stack Developer       Oracle
# 22  Python Programming Language Application Developer    Accenture
# 23               TIBCO Spotfire Application Developer    Accenture
# 24                      Angular Application Developer    Accenture
# 25                      Angular Application Developer    Accenture
# 26                         Application Developer: EAI          IBM
# 27                      Tableau Application Developer    Accenture
# 28                  Teradata BI Application Developer    Accenture
# 29              Google BigQuery Application Developer    Accenture
# 30  Unified Communication and Collaboration Operat...    Accenture
# 31                     React.js Application Developer    Accenture
#
#                 LOCATION                                            SUMMARY
# 0   Hyderabad, Telangana  You will be responsible for defining and devel...
# 1   Hyderabad, Telangana  Software Developer 4-20000O2G Applicants are r...
# 2   Hyderabad, Telangana  You will be responsible for defining and devel...
# 3   Hyderabad, Telangana  Analyze, design develop, troubleshoot and debu...
# 4    Chennai, Tamil Nadu  Key Responsibilities : A:5 years of strong net...
# 5    Chennai, Tamil Nadu  Key Responsibilities : 1 Strong expertise in t...
# 6    Chennai, Tamil Nadu  Key Responsibilities : o Develop, implement, a...
# 7   Bengaluru, Karnataka  As a member of the software engineering divisi...
# 8   Bengaluru, Karnataka  You will be responsible for defining and devel...
# 9   Bengaluru, Karnataka  As a member of the software engineering divisi...
# 10  Bengaluru, Karnataka  As a member of the software engineering divisi...
# 11  Bengaluru, Karnataka  Key Responsibilities : Utilize established dev...
# 12  Bengaluru, Karnataka  Analyze, design develop, troubleshoot and debu...
# 13  Bengaluru, Karnataka  You will be working as an innovator; you will ...
# 14  Bengaluru, Karnataka  Technical Experience : 1 2-3 years of operatio...
# 15  Bengaluru, Karnataka  Key Responsibilities : Design and create data ...
# 16  Bengaluru, Karnataka  As a member of the software engineering divisi...
# 17  Bengaluru, Karnataka  Key Responsibilities : a: Understand Workdays ...
# 18  Bengaluru, Karnataka  As a member of the software engineering divisi...
# 19  Bengaluru, Karnataka  Key Responsibilities : Utilize established dev...
# 20  Bengaluru, Karnataka  Analyze, design develop, troubleshoot and debu...
# 21  Bengaluru, Karnataka  You will be working as an innovator; you will ...
# 22  Bengaluru, Karnataka  Technical Experience : 1 2-3 years of operatio...
# 23  Bengaluru, Karnataka  Key Responsibilities : Design and create data ...
# 24     Pune, Maharashtra  Project Role Description :Design, build and co...
# 25     Pune, Maharashtra  Project Role Description :Design, build and co...
# 26     Pune, Maharashtra  Client interaction and ability to lead and gui...
# 27     Pune, Maharashtra  Key Responsibilities : A : Requirement analysi...
# 28     Pune, Maharashtra  Technical Experience : 1 More than 5 years of ...
# 29      Gurgaon, Haryana  Project Role Description :Design, build and co...
# 30      Gurgaon, Haryana  Project Role Description :Act as software dete...
# 31      Gurgaon, Haryana  Technical Experience : A: Expert knowledge of ...
#
# NO OF SOFTWARE DEVELOPERS JOBS BASED ON COMAPNIES
# Oracle      14
# Infosys      1
# Accenture      17
# IBM      1
#
# NO OF SOFTWARE DEVELOPERS JOBS BASED ON CITIES
# Hyderabad, Telangana      1
# Nanakramguda, Hyderabad, Telangana      1
# Madhapur, Hyderabad, Telangana      1
# L. B. Nagar, Hyderabad, Telangana      1
# Moosapet, Hyderabad, Telangana      1
# Ameerpet, Hyderabad, Telangana      1
# Chennai, Tamil Nadu      1
# Anna Nagar, Chennai, Tamil Nadu      1
# Madipakkam, Chennai, Tamil Nadu      1
# Saidapet, Chennai, Tamil Nadu      1
# Bengaluru, Karnataka      1
# Noida, Uttar Pradesh      1
# Pune, Maharashtra      1
# Baner, Pune, Maharashtra      1
# Viman Nagar, Pune, Maharashtra      1
# Kharadi, Pune, Maharashtra      1
# Kothrud, Pune, Maharashtra      1
# Delhi, Delhi      1
# Krishna Nagar, Delhi, Delhi      1
# Dwarka, Delhi, Delhi      1
# Delhi      1
# Moti Nagar, Delhi      1
# Paschim Vihar, Delhi, Delhi      1
# New Delhi, Delhi      1
# Preet Vihar, Delhi, Delhi      1
# Punjabi Bagh, Delhi, Delhi      1
# Mehrau;I, Delhi      1
# Okhla Industrial Estate, Delhi      1
# Pitampura, Delhi      1
# East of Kailash, Delhi, Delhi      1
# Okhla, Delhi, Delhi      1
# Rohini Sub City, Delhi, Delhi      1
# Punjabi Bagh Sector Iii, Delhi      1
# Gurgaon, Haryana      1
# Manesar, Haryana      1

# %%
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import time
max_results_per_city = 50
city_set = ['Hyderabad%2C+Telangana','hyderbad%2C+Telangana','Chennai%2C+Tamil+Nadu','Bangalore%2C+Karnataka','Bengaluru%2C+Karnataka','Noida%2C+Uttar+Pradesh','Pune%2C+Maharashtra','Delhi','Delhi%2C+Delhi','Gurgaon%2C+Haryana']
col = ['JOB_TITLE', 'COMPANY_NAME', 'LOCATION', 'SUMMARY']
sample_df = pd.DataFrame(columns = col)
res={}
res1={}
#scraping code:
for city in city_set:
    for start in range(0, max_results_per_city,10):
        o=0
        page = requests.get("https://www.indeed.co.in/jobs?q=software+developer&l=" + str(city) + "&start=" + str(start))
        time.sleep(1)  #ensuring at least 1 second between page grabs
        soup = BeautifulSoup(page.text, 'html.parser')
        for div in soup.find_all(name='div', attrs={'class':'row'}):
    #specifying row num for index of job posting in dataframe
            num = (len(sample_df) + 1) 
    #creating an empty list to hold the data for each posting
            job_post = [] 
    #grabbing job title
            for a in div.find_all(name='a', attrs={'data-tn-element':'jobTitle'}):
                         job_post.append(a['title']) 
    #grabbing company name
            company = div.find_all(name='span', attrs={'class':'company'}) 
            if len(company) > 0:
                        for b in company:
                                job_post.append(b.text.strip())
                                if b.text.strip() in res.keys():
                                    res[b.text.strip()]+=1
                                else:
                                    res[b.text.strip()]=1
            else: 
                        sec_try = div.find_all(name='span', attrs={'class':'result-link-source'})
                        for span in sec_try:
                                job_post.append(span.text.strip()) 
                                if span.text.strip() in res.keys():
                                    res[b.text.strip()]+=1
                                else:
                                    res[b.text.strip()]=1
    #grabbing location name
            c = div.findAll('span', attrs={'class': 'location'}) 
            for span in c:
                    job_post.append(span.text.strip())
                    if span.text.strip() in res1.keys():
                            res1[span.text.strip()]+=1
                    else:
                            res1[span.text.strip()]=1
    #grabbing summary text
            d = div.findAll('div', attrs={'class': 'summary'}) #it conatins the exprience for the job
            for span in d:
                        s=span.text.strip()
                        s1=s.replace('\n',"")
                        job_post.append(s1)   
    #appending list of job post info to dataframe at index num
            if(len(job_post)>3):
                sample_df = sample_df.append({'JOB_TITLE' :job_post[0], 'COMPANY_NAME' :job_post[1], 'LOCATION' : job_post[2],'SUMMARY':job_post[3]},ignore_index = True)
print(sample_df)
print()
print("NO OF SOFTWARE DEVELOPERS JOBS BASED ON COMAPNIES")
for i in res:
    print(i,"    ",res[i],end="\n")
print()
print("NO OF SOFTWARE DEVELOPERS JOBS BASED ON CITIES")
for j in res1:
    print(j,"    ",res1[j],end="\n")
